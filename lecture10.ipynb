# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('../StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df['total_score'] = df['math score'] + df['reading score'] + df['writing score']
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df1 = pd.DataFrame(df.groupby(by='race/ethnicity',axis=0)['total_score'].sum())
df2 = pd.DataFrame(df['race/ethnicity'].value_counts())
print(df2)
print(df1)
df3 = pd.DataFrame(df1['total_score']/df2['count'] ,columns=['avg']).reset_index()
df3
# Out:
#                 count
# race/ethnicity
# group C           319
# group D           262
# group B           190
# group E           140
# group A            89
#                 total_score
# race/ethnicity
# group A               16819
# group B               37317
# group C               64245
# group D               54375
# group E               30556
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10416\3824053472.py:1: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   df1 = pd.DataFrame(df.groupby(by='race/ethnicity',axis=0)['total_score'].sum())
#   race/ethnicity         avg
# 0        group A  188.977528
# 1        group B  196.405263
# 2        group C  201.394984
# 3        group D  207.538168
# 4        group E  218.257143

# %%
sns.catplot(x='race/ethnicity',y='avg',kind='bar',data=df3)
plt.plot()
# Out:
# []

# %%
sns.catplot(x='race/ethnicity',y='math score',hue='test preparation course',data=df,kind='violin')
plt.show()

# %%
sns.catplot(x='race/ethnicity',data=df,kind='count')
plt.show()

# %%
group_sex_division = pd.DataFrame(df.groupby(by='race/ethnicity',axis=0)['gender'].value_counts()).reset_index()
group_sex_division
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10416\3800816643.py:1: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   group_sex_division = pd.DataFrame(df.groupby(by='race/ethnicity',axis=0)['gender'].value_counts()).reset_index()
#   race/ethnicity  gender  count
# 0        group A    male     53
# 1        group A  female     36
# 2        group B  female    104
# 3        group B    male     86
# 4        group C  female    180
# 5        group C    male    139
# 6        group D    male    133
# 7        group D  female    129
# 8        group E    male     71
# 9        group E  female     69

# %%
sns.catplot(x='race/ethnicity',y='count',hue='gender',data=group_sex_division,kind='bar')
plt.show()
