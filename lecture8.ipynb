# %%
import pandas as pd

# %%
excel = pd.read_csv("../top_1000_details.csv")
excel
# Out:
#               id   viewCount   likeCount  favoriteCount  commentCount  \
# 0    BBAyRBTfsOU  1589926035  13163890.0              0        359141
# 1    sCbbMZ-q4-I  1394834659  11013187.0              0        341677
# 2    JFcgOboQZ08  1306259000   5587227.0              0        188513
# 3    vu5-aKf_QqA  1235684404   3569186.0              0         84749
# 4    f6vY6tYvKGA  1222902136   4065996.0              0         94157
# ..           ...         ...         ...            ...           ...
# 995  uSb0M_UQE1o    56988240    787064.0              0         25903
# 996  3qKi29UR2g4    56828200    475589.0              0         18140
# 997  ldAgG1M4qZg    56810604    652595.0              0         37387
# 998  acdKE2hja7w    56807771    200798.0              0          3161
# 999  id5_3dKvEBg    56790897    641576.0              0         22789
#
#                                                  title  \
# 0    Vaaste Song: Dhvani Bhanushali, Tanishk Bagchi...
# ...

# %%
excel.isnull().sum()
# Out:
# id               0
# viewCount        0
# likeCount        2
# favoriteCount    0
# commentCount     0
# title            0
# description      0
# thumbnail_url    0
# published_at     0
# dtype: int64

# %%
excel1 =excel.dropna(inplace =False)
excel1.isnull().sum()
# Out:
# id               0
# viewCount        0
# likeCount        0
# favoriteCount    0
# commentCount     0
# title            0
# description      0
# thumbnail_url    0
# published_at     0
# dtype: int64

# %%
excel.dropna(inplace=True)
excel.isnull().sum()
# Out:
# id               0
# viewCount        0
# likeCount        0
# favoriteCount    0
# commentCount     0
# title            0
# description      0
# thumbnail_url    0
# published_at     0
# dtype: int64

# %%
#drop column

excel2 =excel.drop(['thumbnail_url','favoriteCount'],axis =1)
excel2
# Out:
#               id   viewCount   likeCount  commentCount  \
# 0    BBAyRBTfsOU  1589926035  13163890.0        359141
# 1    sCbbMZ-q4-I  1394834659  11013187.0        341677
# 2    JFcgOboQZ08  1306259000   5587227.0        188513
# 3    vu5-aKf_QqA  1235684404   3569186.0         84749
# 4    f6vY6tYvKGA  1222902136   4065996.0         94157
# ..           ...         ...         ...           ...
# 995  uSb0M_UQE1o    56988240    787064.0         25903
# 996  3qKi29UR2g4    56828200    475589.0         18140
# 997  ldAgG1M4qZg    56810604    652595.0         37387
# 998  acdKE2hja7w    56807771    200798.0          3161
# 999  id5_3dKvEBg    56790897    641576.0         22789
#
#                                                  title  \
# 0    Vaaste Song: Dhvani Bhanushali, Tanishk Bagchi...
# 1    Lut Gaye (Full Song) Emraan Hashmi, Yukti | Ju...
# 2    DILBAR Lyrical | Satyameva Jayate |John Abraha...
# 3    SIMMBA: Aankh Marey Lyrical | Ranveer Singh, S...
# ...

# %%
excel.dropna(inplace=True)
excel
# Out:
#               id   viewCount   likeCount  favoriteCount  commentCount  \
# 0    BBAyRBTfsOU  1589926035  13163890.0              0        359141
# 1    sCbbMZ-q4-I  1394834659  11013187.0              0        341677
# 2    JFcgOboQZ08  1306259000   5587227.0              0        188513
# 3    vu5-aKf_QqA  1235684404   3569186.0              0         84749
# 4    f6vY6tYvKGA  1222902136   4065996.0              0         94157
# ..           ...         ...         ...            ...           ...
# 995  uSb0M_UQE1o    56988240    787064.0              0         25903
# 996  3qKi29UR2g4    56828200    475589.0              0         18140
# 997  ldAgG1M4qZg    56810604    652595.0              0         37387
# 998  acdKE2hja7w    56807771    200798.0              0          3161
# 999  id5_3dKvEBg    56790897    641576.0              0         22789
#
#                                                  title  \
# 0    Vaaste Song: Dhvani Bhanushali, Tanishk Bagchi...
# ...

# %%
excel.fillna(excel.likeCount.mean(),inplace=True)

# %%
excel.isnull().sum()
# Out:
# id               0
# viewCount        0
# likeCount        0
# favoriteCount    0
# commentCount     0
# title            0
# description      0
# thumbnail_url    0
# published_at     0
# dtype: int64

# %%
superstore= pd.read_excel("../superstore.xlsx")
superstore
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 1          2  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 2          3  CA-2013-138688 2013-06-13 2013-06-17    Second Class
# 3          4  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# 4          5  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2011-110422 2011-01-22 2011-01-24    Second Class
# 9990    9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 9991    9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 9992    9993  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 9993    9994  CA-2014-119914 2014-05-05 2014-05-10    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
superstore.loc[:,'Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
superstore['Sales'].sum()
# Out:
# 2297200.8603000003

# %%
#groupby Sales

df =superstore.groupby(by='Region',axis=0)['Sales'].sum()
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4852\1821662601.py:3: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   df =superstore.groupby(by='Region',axis=0)['Sales'].sum()
# Region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725457.8245
# Name: Sales, dtype: float64

# %%
profit =pd.DataFrame(superstore.groupby(by='Sub-Category',axis=0)['Profit'].sum())
sales = pd.DataFrame(superstore.groupby(by='Sub-Category',axis=0)['Sales'].sum())
print(profit)
print(sales)
# Out:
#                   Profit
# Sub-Category
# Accessories   41936.6357
# Appliances    18138.0054
# Art            6527.7870
# Binders       30221.7633
# Bookcases     -3472.5560
# Chairs        26590.1663
# Copiers       55617.8249
# Envelopes      6964.1767
# Fasteners       949.5182
# Furnishings   13059.1436
# Labels         5546.2540
# Machines       3384.7569
# Paper         34053.5693
# Phones        44515.7306
# Storage       21278.8264
# Supplies      -1189.0995
# Tables       -17725.4811
#                     Sales
# Sub-Category
# Accessories   167380.3180
# Appliances    107532.1610
# Art            27118.7920
# Binders       203412.7330
# Bookcases     114879.9963
# Chairs        328449.1030
# Copiers       149528.0300
# Envelopes      16476.4020
# Fasteners       3024.2800
# Furnishings    91705.1640
# Labels         12486.3120
# Machines      189238.6310
# Paper          78479.2060
# Phones        330007.0540
# Storage       223843.6080
# Supplies       46673.5380
# ...

# %%
df =profit.merge(sales,how='inner',on='Sub-Category')
df['Percentage'] = (df['Profit']/df['Sales'])*100

df.sort_values(['Percentage'],ascending=False,inplace=True)
# df.to_csv('profit_percent2.csv',header=True)
df
# Out:
#                   Profit        Sales  Percentage
# Sub-Category
# Labels         5546.2540   12486.3120   44.418672
# Paper         34053.5693   78479.2060   43.391837
# Envelopes      6964.1767   16476.4020   42.267582
# Copiers       55617.8249  149528.0300   37.195585
# Fasteners       949.5182    3024.2800   31.396504
# Accessories   41936.6357  167380.3180   25.054700
# Art            6527.7870   27118.7920   24.071083
# Appliances    18138.0054  107532.1610   16.867517
# Binders       30221.7633  203412.7330   14.857361
# Furnishings   13059.1436   91705.1640   14.240358
# Phones        44515.7306  330007.0540   13.489327
# Storage       21278.8264  223843.6080    9.506113
# Chairs        26590.1663  328449.1030    8.095673
# Machines       3384.7569  189238.6310    1.788618
# Supplies      -1189.0995   46673.5380   -2.547695
# Bookcases     -3472.5560  114879.9963   -3.022768
# Tables       -17725.4811  206965.5320   -8.564460

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
arr= np.random.randint(1,10,15)
fig =plt.plot(arr)
plt.show(fig)

# %%
sin = np.sin([0,np.pi/2, np.pi, 3* np.pi/2, 2*np.pi])
fig =plt.plot(sin,marker='*',color='b')

plt.title("plot of sine graph")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show(fig)

# %%
x= np.random.random((4,))*100
print(x)
y= np.array(['Science','Math','Hindi','English'])
fig =plt.pie(x,labels=y)
plt.plot(fig)
# Out:
# [31.49042571  0.71840082 42.27388991 50.23792712]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 5
#       3 y= np.array(['Science','Math','Hindi','English'])
#       4 fig =plt.pie(x,labels=y)
# ----> 5 plt.plot(fig)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# ...

# %%
x= np.random.random((4,))*100
print(x)
y= np.array(['Science','Math','Hindi','English'])

fig =plt.bar(y,x)
plt.show(fig)
# Out:
# [67.15338895 51.79939483  5.66681643 38.03572415]

# %%
x= np.random.random((5,))*100
print(x)
y= np.array(['Science','Math','Hindi','English','Social Study'])

fig =plt.scatter(y,x)
plt.show(fig)
# Out:
# [62.82461484 85.92360431 45.68454782 87.29721369 55.78336409]

# %%
x= np.random.random((5,))*100
print(x)
x.sort()
y= np.array(['Science','Math','Hindi','English'])

fig =plt.hist(x)
plt.show(fig)
# Out:
# [ 3.52859785 58.89201996 56.74088919 73.76694009 89.98644016]
